# %% [markdown]
# Importamos las librerias a utilizar

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from nltk import FreqDist
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\THERMALTAKE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Importamos cada dataframe y lo guardamos en una variable con sus respectivos nombres

# %%
df_coursera_courses = pd.read_csv("Coursera_courses.csv")
df_coursera_reviews = pd.read_csv("Coursera_reviews.csv")
df_edx_courses = pd.read_csv("edx_courses.csv")
df_udemy_courses = pd.read_csv("udemy_courses.csv")

# %% [markdown]
# Verificamos lo que contiene

# %%
df_coursera_courses.head()
# Out:
#                                                 name  \
# 0                                   Machine Learning
# 1                                  Indigenous Canada
# 2                          The Science of Well-Being
# 3                     Technical Support Fundamentals
# 4  Become a CBRS Certified Professional Installer...
#
#                  institution  \
# 0        Stanford University
# 1      University of Alberta
# 2            Yale University
# 3                     Google
# 4  Google - Spectrum Sharing
#
#                                           course_url  \
# 0    https://www.coursera.org/learn/machine-learning
# 1   https://www.coursera.org/learn/indigenous-canada
# 2  https://www.coursera.org/learn/the-science-of-...
# 3  https://www.coursera.org/learn/technical-suppo...
# 4  https://www.coursera.org/learn/google-cbrs-cpi...
#
#                         course_id
# 0                machine-learning
# 1               indigenous-canada
# 2       the-science-of-well-being
# 3  technical-support-fundamentals
# 4        google-cbrs-cpi-training

# %% [markdown]
# Pasamos todos las mayusculas a minusculas

# %%
df_coursera_courses = df_coursera_courses.apply(lambda x: x.str.lower())

# %% [markdown]
# Verificamos los cambios

# %%
df_coursera_courses.head()
# Out:
#                                                 name  \
# 0                                   machine learning
# 1                                  indigenous canada
# 2                          the science of well-being
# 3                     technical support fundamentals
# 4  become a cbrs certified professional installer...
#
#                  institution  \
# 0        stanford university
# 1      university of alberta
# 2            yale university
# 3                     google
# 4  google - spectrum sharing
#
#                                           course_url  \
# 0    https://www.coursera.org/learn/machine-learning
# 1   https://www.coursera.org/learn/indigenous-canada
# 2  https://www.coursera.org/learn/the-science-of-...
# 3  https://www.coursera.org/learn/technical-suppo...
# 4  https://www.coursera.org/learn/google-cbrs-cpi...
#
#                         course_id
# 0                machine-learning
# 1               indigenous-canada
# 2       the-science-of-well-being
# 3  technical-support-fundamentals
# 4        google-cbrs-cpi-training

# %% [markdown]
# Verificamos existencia de nulos y registros duplicados

# %%
df_coursera_courses.isnull().sum()
# Out:
# name           0
# institution    0
# course_url     0
# course_id      0
# dtype: int64

# %%
df_coursera_courses.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Realizamos el WordCloud

# %%
stopwords1=stopwords.words("english")
titles = df_coursera_courses["name"].tolist()
fdist = FreqDist (titles)

# %% [markdown]
# Calcula la frecuencia de aparición de cada palabra

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='black',
                stopwords = stopwords1,
                colormap = 'viridis',
                min_font_size = 10).generate_from_frequencies(fdist)

# %% [markdown]
# Visualizamos el WordCloud

# %%
plt.figure(figsize = (8, 8), facecolor = "black")
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
df_coursera_courses.drop("course_url",axis=1, inplace=True)

# %% [markdown]
# Visualizamos el DataFrame de Coursera_reviews

# %%
df_coursera_reviews.head()
# Out:
#                                              reviews       reviewers  \
# 0  Pretty dry, but I was able to pass with just t...     By Robert S
# 1  would be a better experience if the video and ...  By Gabriel E R
# 2  Information was perfect! The program itself wa...      By Jacob D
# 3  A few grammatical mistakes on test made me do ...       By Dale B
# 4  Excellent course and the training provided was...       By Sean G
#
#    date_reviews  rating                 course_id
# 0  Feb 12, 2020       4  google-cbrs-cpi-training
# 1  Sep 28, 2020       4  google-cbrs-cpi-training
# 2  Apr 08, 2020       4  google-cbrs-cpi-training
# 3  Feb 24, 2020       4  google-cbrs-cpi-training
# 4  Jun 18, 2020       4  google-cbrs-cpi-training

# %% [markdown]
# Verificamos existencia de nulos y registros duplicados

# %%
df_coursera_reviews.isnull().sum()
# Out:
# reviews         140
# reviewers         0
# date_reviews      0
# rating            0
# course_id         0
# dtype: int64

# %%
df_coursera_reviews.duplicated().sum()
# Out:
# 934764

# %% [markdown]
# Eliminamos solamente los valores duplicados

# %%
df_coursera_reviews.drop_duplicates(inplace=True)

# %% [markdown]
# Pasamos las mayusculas a minusculas y transformamos los valores a str

# %%
df_coursera_reviews['reviewers'] = df_coursera_reviews['reviewers'].apply(lambda x: x.lower())
df_coursera_reviews['reviews'] = df_coursera_reviews['reviews'].astype(str).apply(lambda x: x.lower())

# %% [markdown]
# Visualizamos los cambios

# %%
df_coursera_reviews.head()
# Out:
#                                              reviews       reviewers  \
# 0  pretty dry, but i was able to pass with just t...     by robert s
# 1  would be a better experience if the video and ...  by gabriel e r
# 2  information was perfect! the program itself wa...      by jacob d
# 3  a few grammatical mistakes on test made me do ...       by dale b
# 4  excellent course and the training provided was...       by sean g
#
#    date_reviews  rating                 course_id
# 0  Feb 12, 2020       4  google-cbrs-cpi-training
# 1  Sep 28, 2020       4  google-cbrs-cpi-training
# 2  Apr 08, 2020       4  google-cbrs-cpi-training
# 3  Feb 24, 2020       4  google-cbrs-cpi-training
# 4  Jun 18, 2020       4  google-cbrs-cpi-training

# %% [markdown]
# Realizamos el WordCloud

# %%
stopwords3=stopwords.words("english")
titles = df_coursera_reviews["reviews"].tolist()
fdist = FreqDist (titles)

# %%
# Calcula la frecuencia de aparición de cada palabra
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='black',
                stopwords = stopwords3,
                colormap = 'viridis',
                min_font_size = 10).generate_from_frequencies(fdist)

# %% [markdown]
# Visualizamos el WordCloud

# %%
plt.figure(figsize = (8, 8), facecolor = "black")
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# Eliminamos las columnas que no utilizaremos

# %%
df_coursera_reviews.drop(["reviews","reviewers"],axis=1, inplace=True)

# %% [markdown]
# Verificamos lo que contiene

# %%
df_edx_courses.head()
# Out:
#                                                title  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                                              summary n_enrolled  \
# 0  Learn essential strategies for successful onli...    124,980
# 1  This course is a "no prerequisite" introductio...    293,864
# 2  An introduction to the intellectual enterprise...  2,442,271
# 3  Through inspiring examples and stories, discov...    129,555
# 4     This course is part of a MicroMasters® Program     81,140
#
#                            course_type                            institution  \
# 0              Self-paced on your time                                    edX
# 1              Self-paced on your time             The University of Michigan
# 2              Self-paced on your time                     Harvard University
# 3  Instructor-led on a course schedule  Massachusetts Institute of Technology
# 4              Self-paced on your time     University of California, Berkeley
#
#                                          instructors         Level  \
# 0            Nina Huntemann-Robyn Belair-Ben Piscopo  Introductory
# 1                                  Charles Severance  Introductory
# 2                 David J. Malan-Doug Lloyd-Brian Yu  Introductory
# 3  Dimitris Bertsimas-Allison O'Hair-John Silberh...  Intermediate
# 4                                     Stephan Sorger  Introductory
#
#                         subject language subtitles         course_effort  \
# 0  Education & Teacher Training  English   English    2–3 hours per week
# 1              Computer Science  English   English    2–4 hours per week
# 2              Computer Science  English   English   6–18 hours per week
# 3    Data Analysis & Statistics  English   English  10–15 hours per week
# 4              Computer Science  English   English    5–7 hours per week
#
#   course_length                                         price  \
# 0       2 Weeks   FREE-Add a Verified Certificate for $49 USD
# 1       7 Weeks   FREE-Add a Verified Certificate for $49 USD
# 2      12 Weeks   FREE-Add a Verified Certificate for $90 USD
# 3      13 Weeks  FREE-Add a Verified Certificate for $199 USD
# 4       4 Weeks  FREE-Add a Verified Certificate for $249 USD
#
#                                   course_description  \
# 0  Designed for those who are new to elearning, t...
# 1  This course aims to teach everyone the basics ...
# 2  This is CS50x , Harvard University's introduct...
# 3  In the last decade, the amount of data availab...
# 4  Begin your journey in a new career in marketin...
#
#                                      course_syllabus  \
# 0  Welcome - We start with opportunities to meet ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           course_url
# 0     https://www.edx.org/course/how-to-learn-online
# 1  https://www.edx.org/course/programming-for-eve...
# 2  https://www.edx.org/course/cs50s-introduction-...
# 3      https://www.edx.org/course/the-analytics-edge
# 4  https://www.edx.org/course/marketing-analytics...

# %% [markdown]
# Pasamos las Mayusculas a minuscula

# %%
df_edx_courses = df_edx_courses.apply(lambda x: x.str.lower())

# %% [markdown]
# Realizamos el WordCloud

# %%
stopwords3 = stopwords.words('english')

# %%
titles = df_edx_courses['title'].tolist()

# %%
fdist = FreqDist(titles)

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='black',
                stopwords = stopwords3,
                colormap = 'viridis',
                min_font_size = 10).generate_from_frequencies(fdist)

# %% [markdown]
# Eliminamos las tablas que no utilizaremos

# %%
df_edx_courses.drop(["summary","institution","instructors","subtitles", "course_effort","course_length","course_description","course_syllabus","course_url"],axis=1,inplace=True)

# %% [markdown]
# Visualiza el WordCloud

# %%
plt.figure(figsize = (8, 8), facecolor = "black")
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# Verificamos lo que contiene

# %%
df_udemy_courses.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %% [markdown]
# Normalizamos los valores y cambiamos las mayusculas a minusculas

# %%
df_udemy_courses['course_title'] = df_udemy_courses['course_title'].str.replace(',','').str.replace('.','').str.replace('-','')
# Out:
# C:\Users\THERMALTAKE\AppData\Local\Temp\ipykernel_10792\1437018340.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_udemy_courses['course_title'] = df_udemy_courses['course_title'].str.replace(',','').str.replace('.','').str.replace('-','')

# %%
df_udemy_courses['course_title'] = df_udemy_courses['course_title'].apply(lambda x: x.lower())

# %%
df_udemy_courses['level'] = df_udemy_courses['level'].apply(lambda x: x.lower())
df_udemy_courses['subject'] = df_udemy_courses['subject'].apply(lambda x: x.lower())

# %% [markdown]
# Verificamos si tiene nulos o duplicados

# %%
df_udemy_courses.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df_udemy_courses.duplicated().sum()
# Out:
# 6

# %% [markdown]
# Eliminamos los duplicados

# %%
df_udemy_courses.drop_duplicates(inplace=True)

# %% [markdown]
# Verificamos los cambios

# %%
df_udemy_courses.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 ultimate investment banking course
# 1    1113822  complete gst course & certification  grow your...
# 2    1006314  financial modeling for business analysts and c...
# 3    1210588  beginner to pro  financial analysis in excel 2017
# 4    1011058       how to maximize your profits trading options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          all levels
# 1             2792          923           274          all levels
# 2             2174           74            51  intermediate level
# 3             2451           11            36          all levels
# 4             1276           45            26  intermediate level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  business finance
# 1              39.0  2017-03-09T16:34:20Z  business finance
# 2               2.5  2016-12-19T19:26:30Z  business finance
# 3               3.0  2017-05-30T20:07:24Z  business finance
# 4               2.0  2016-12-13T14:57:18Z  business finance

# %%
df_udemy_courses.is_paid=df_udemy_courses.is_paid.replace(True,"Pago").replace(False,"No Pago")

# %%
df_udemy_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3672 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   int64
#  5   num_subscribers      3672 non-null   int64
#  6   num_reviews          3672 non-null   int64
#  7   num_lectures         3672 non-null   int64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   float64
#  10  published_timestamp  3672 non-null   object
#  11  subject              3672 non-null   object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 372.9+ KB

# %% [markdown]
# Realizamos el WordCloud

# %%
stopwords4=stopwords.words("english")

# %%
titles = df_udemy_courses["course_title"].tolist()

# %%
fdist = FreqDist (titles)

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='black',
                      stopwords=stopwords4,
                      max_words=50,
                      max_font_size=40,
                      scale=5,
                      random_state=2,
                min_font_size = 10).generate_from_frequencies(fdist)

# %% [markdown]
# Visualiza el WordCloud

# %%
plt.figure(figsize = (8, 8), facecolor = "black")
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# Eliminamso las columnas que no utilizaremos

# %%
df_udemy_courses.drop(["course_id","url"],axis=1, inplace=True)

# %% [markdown]
# Guardamos los datos modificados para luego poder trabajar con ellos

# %%
df_coursera_courses.to_csv("coursera_coursespowerbi.csv",index=False)
df_coursera_reviews.to_csv("coursera_reviewspowerbi.csv",index=False)
df_edx_courses.to_csv("edx_coursespowerbi.csv",index=False)
df_udemy_courses.to_csv("udemy_coursespowerbi.csv",index=False)
